# %%
import loompy
import numpy as np
import logging
import os
import matplotlib.pyplot as plt
from cytograph.preprocessing import Normalizer
from cytograph.enrichment.binary_differential_expression import BinaryDifferentialExpression
from diffxpy.api.test import pairwise
from goatools import obo_parser
import Bio

import logging
logger = logging.getLogger()
logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.INFO,
    datefmt='%H:%M:%S')

import pickle as pkl

# %%
f_dir = '/proj/GBM/FRESH_20210607'
f = os.path.join(f_dir, 'data' , 'GBM_Tumor.loom')
f_agg = os.path.join(f_dir, 'data' , 'GBM_Tumor.agg.loom')

# %%
import sys
from Bio import Entrez

# *Always* tell NCBI who you are
Entrez.email = "john.doe@mail.com"
 
def retrieve_annotation(id_list):
 
    """Annotates Entrez Gene IDs using Bio.Entrez, in particular epost (to
    submit the data to NCBI) and esummary to retrieve the information. 
    Returns a list of dictionaries with the annotations."""
 
    # This below tests for search by gene symbol
    request = Entrez.epost("gene",id=",".join(id_list))
    try:
        result = Entrez.read(request)
    except RuntimeError as e:
        #FIXME: How generate NAs instead of causing an error with invalid IDs?
        print("An error occurred while retrieving the annotations.")
        print("The error returned was %s" % e)
        sys.exit(-1)
 
    webEnv = result["WebEnv"]
    queryKey = result["QueryKey"]
    data = Entrez.esummary(db="gene", webenv=webEnv, query_key =
            queryKey)
    annotations = Entrez.read(data)
 
    print("Retrieved %d annotations for %d genes" % (len(annotations), len(id_list)))
    return annotations

with loompy.connect(f) as ds:
    #Search for Gene ID, then find annotation
    id_list = []
    for x in ds.ra.Gene:
        sterm = x + '[sym] "Homo Sapiens"[orgn]'
        handle = Entrez.esearch(db="gene", retmode = "xml", term = x )
        record = Entrez.read(handle)
        if len(record) > 0:
            IDArray = record["IdList"]
            toString = str(IDArray[0])
            id_list.append(toString)

    annotation = retrieve_annotation(id_list)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/lib/condor/execute/dir_53096/ipykernel_31225/198655431.py in <module>
#      38         record = Entrez.read(handle)
#      39         IDArray = record["IdList"]
# ---> 40         toString = str(IDArray[0])
#      41         id_list.append(toString)
#      42         print('.')
#
# IndexError: list index out of range

# %%
# ?Entrez.esearch
# Out:
# Signature: Entrez.esearch(db, term, **keywds)
# Docstring:
# Run an Entrez search and return a handle to the results.
#
# ESearch searches and retrieves primary IDs (for use in EFetch, ELink
# and ESummary) and term translations, and optionally retains results
# for future use in the user's environment.
#
# See the online documentation for an explanation of the parameters:
# http://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch
#
# Return a handle to the results which are always in XML format.
#
# Raises an IOError exception if there's a network error.
#
# Short example:
#
# >>> from Bio import Entrez
# >>> Entrez.email = "Your.Name.Here@example.org"
# >>> handle = Entrez.esearch(db="nucleotide", retmax=10, term="opuntia[ORGN] accD", idtype="acc")
# >>> record = Entrez.read(handle)
# >>> handle.close()
# >>> int(record["Count"]) >= 2
# True
# >>> "EF590893.1" in record["IdList"]
# True
# >>> "EF590892.1" in record["IdList"]
# True
# File:      ~/anaconda3/envs/cytograph/lib/python3.9/site-packages/Bio/Entrez/__init__.py
# Type:      function

# %%
with loompy.connect(f) as ds:
    print(ds.ra.Gene[:5])
    print(ds.ra.Accession[:5])
#     with loompy.connect(f_agg) as dsagg:        
#         Tumor_clusters = np.unique(ds.ca.Clusters[np.where(ds.ca.Subset=='Tumor')[0]])
#         print(dsagg.ca.AutoAnnotation[Tumor_clusters])
# Out:
# ['CDH19' 'KCNK10' 'SYT6' 'SCN9A' 'U91319.1']
# ['ENSG00000071991' 'ENSG00000100433' 'ENSG00000134207' 'ENSG00000169432'
#  'ENSG00000262801']

# %%
# with loompy.connect(f) as ds:
#     Tumor_clusters = set(np.unique(ds.ca.Clusters[np.where(ds.ca.Subset=='Tumor')[0]]))
#     labels = np.array(['Tumor' if x in Tumor_clusters else 'Control' for x in ds.ca.Clusters])
    
#     BDE = BinaryDifferentialExpression()
#     logging.info(f'Fitting data')
#     BDE.fit(ds, labels)
#     logging.info(f'Calculate differential expression')
#     selected = BDE.select('Tumor', 'Control')
    
#     with open('/proj/GBM/FRESH_20210607/misc/differntial.pkl', "wb") as output_file:
#         pkl.dump([selected, BDE], output_file)

# %%
obo_path = '/datb/sl/camiel/tumor/ref/go-basic.obo'

go = obo_parser.GODag(obo_path)
# Out:
# /datb/sl/camiel/tumor/ref/go-basic.obo: fmt(1.2) rel(2021-06-16) 47,230 GO Terms

# %%
relevant_terms = []
key_word = 'cell surface'

for go_term in go:
    if key_word in go[go_term].name:
        relevant_terms.append(go_term)
        
logging.info(f'{len(relevant_terms)} relevant terms out of {len(go.keys())}')
# Out:
# 17:03:19 INFO     32 relevant terms out of 47230

# %%
for i in relevant_terms:
    print(f'{i} {go[i].name}')
# Out:
# GO:0002220 innate immune response activating cell surface receptor signaling pathway
# GO:0002429 immune response-activating cell surface receptor signaling pathway
# GO:0002433 immune response-regulating cell surface receptor signaling pathway involved in phagocytosis
# GO:0002752 cell surface pattern recognition receptor signaling pathway
# GO:0002767 immune response-inhibiting cell surface receptor signaling pathway
# GO:0002768 immune response-regulating cell surface receptor signaling pathway
# GO:0007166 cell surface receptor signaling pathway
# GO:0009930 longitudinal side of cell surface
# GO:0009986 cell surface
# GO:0020030 infected host cell surface knob
# GO:0033575 protein glycosylation at cell surface
# GO:0033580 protein galactosylation at cell surface
# GO:0033626 positive regulation of integrin activation by cell surface receptor linked signal transduction
# GO:0034394 protein localization to cell surface
# GO:0038184 cell surface bile acid receptor signaling pathway
# GO:0044228 host cell surface
# GO:0046789 host cell surface receptor binding
# GO:0046812 host cell surface binding
# GO:0061311 cell surface receptor signaling pathway involved in heart development
# GO:0070782 phosphatidylserine exposure on apoptotic cell surface
# GO:0071980 cell surface adhesin-mediated gliding motility
# GO:0097610 cell surface furrow
# GO:0106139 symbiont cell surface
# GO:1905114 cell surface receptor signaling pathway involved in cell-cell signaling
# GO:1905780 regulation of phosphatidylserine exposure on apoptotic cell surface
# GO:1905781 negative regulation of phosphatidylserine exposure on apoptotic cell surface
# GO:1905782 positive regulation of phosphatidylserine exposure on apoptotic cell surface
# GO:2000008 regulation of protein localization to cell surface
# GO:2000009 negative regulation of protein localization to cell surface
# GO:2000010 positive regulation of protein localization to cell surface
# GO:0009929 cell surface
# GO:0009928 cell surface

# %%
go['GO:0009928']
# Out:
# GOTerm('GO:0009986'):
#   id:GO:0009986
#   item_id:GO:0009986
#   name:cell surface
#   namespace:cellular_component
#   _parents: 1 items
#     GO:0110165
#   parents: 1 items
#     GO:0110165	level-01	depth-01	cellular anatomical entity [cellular_component]
#   children: 0 items
#   level:2
#   depth:2
#   is_obsolete:False
#   alt_ids: 2 items
#     GO:0009929
#     GO:0009928

# %%
go
# Out:
# {'GO:0000001': GOTerm('GO:0000001'):
#    id:GO:0000001
#    item_id:GO:0000001
#    name:mitochondrion inheritance
#    namespace:biological_process
#    _parents: 2 items
#      GO:0048308
#      GO:0048311
#    parents: 2 items
#      GO:0048308	level-05	depth-05	organelle inheritance [biological_process]
#      GO:0048311	level-05	depth-06	mitochondrion distribution [biological_process]
#    children: 0 items
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000002': GOTerm('GO:0000002'):
#    id:GO:0000002
#    item_id:GO:0000002
#    name:mitochondrial genome maintenance
#    namespace:biological_process
#    _parents: 1 items
#      GO:0007005
#    parents: 1 items
#      GO:0007005	level-05	depth-05	mitochondrion organization [biological_process]
#    children: 0 items
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000003': GOTerm('GO:0000003'):
#    id:GO:0000003
#    item_id:GO:0000003
#    name:reproduction
#    namespace:biological_process
#    _parents: 1 items
#      GO:0008150
#    parents: 1 items
#      GO:0008150	level-00	depth-00	biological_process [biological_process]
#    children: 5 items
#      GO:0019953	level-02	depth-03	sexual reproduction [biological_process]
#      GO:0019954	level-02	depth-02	asexual reproduction [biological_process]
#      GO:0032504	level-02	depth-02	multicellular organism reproduction [biological_process]
#      GO:0032505	level-02	depth-02	reproduction of a single-celled organism [biological_process]
#      GO:0075325	level-02	depth-02	spore dispersal [biological_process]
#    level:1
#    depth:1
#    is_obsolete:False
#    alt_ids: 2 items
#      GO:0019952
#      GO:0050876,
#  'GO:0000006': GOTerm('GO:0000006'):
#    id:GO:0000006
#    item_id:GO:0000006
#    name:high-affinity zinc transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005385
#    parents: 1 items
#      GO:0005385	level-07	depth-08	zinc ion transmembrane transporter activity [molecular_function]
#    children: 0 items
#    level:8
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000007': GOTerm('GO:0000007'):
#    id:GO:0000007
#    item_id:GO:0000007
#    name:low-affinity zinc ion transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005385
#    parents: 1 items
#      GO:0005385	level-07	depth-08	zinc ion transmembrane transporter activity [molecular_function]
#    children: 0 items
#    level:8
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000009': GOTerm('GO:0000009'):
#    id:GO:0000009
#    item_id:GO:0000009
#    name:alpha-1,6-mannosyltransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0000030
#    parents: 1 items
#      GO:0000030	level-05	depth-05	mannosyltransferase activity [molecular_function]
#    children: 2 items
#      GO:0052917	level-07	depth-07	dolichyl-P-Man:Man(7)GlcNAc(2)-PP-dolichol alpha-1,6-mannosyltransferase [molecular_function]
#      GO:0033164	level-07	depth-07	glycolipid 1,6-alpha-mannosyltransferase activity [molecular_function]
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000010': GOTerm('GO:0000010'):
#    id:GO:0000010
#    item_id:GO:0000010
#    name:trans-hexaprenyltranstransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0004659
#    parents: 1 items
#      GO:0004659	level-04	depth-04	prenyltransferase activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000011': GOTerm('GO:0000011'):
#    id:GO:0000011
#    item_id:GO:0000011
#    name:vacuole inheritance
#    namespace:biological_process
#    _parents: 2 items
#      GO:0048308
#      GO:0007033
#    parents: 2 items
#      GO:0007033	level-05	depth-05	vacuole organization [biological_process]
#      GO:0048308	level-05	depth-05	organelle inheritance [biological_process]
#    children: 0 items
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000012': GOTerm('GO:0000012'):
#    id:GO:0000012
#    item_id:GO:0000012
#    name:single strand break repair
#    namespace:biological_process
#    _parents: 1 items
#      GO:0006281
#    parents: 1 items
#      GO:0006281	level-05	depth-07	DNA repair [biological_process]
#    children: 2 items
#      GO:1990396	level-07	depth-10	single-strand break repair via homologous recombination [biological_process]
#      GO:1903823	level-07	depth-09	telomere single strand break repair [biological_process]
#    level:6
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000014': GOTerm('GO:0000014'):
#    id:GO:0000014
#    item_id:GO:0000014
#    name:single-stranded DNA endodeoxyribonuclease activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0004520
#    parents: 1 items
#      GO:0004520	level-05	depth-06	endodeoxyribonuclease activity [molecular_function]
#    children: 2 items
#      GO:1990601	level-07	depth-08	5' overhang single-stranded DNA endodeoxyribonuclease activity [molecular_function]
#      GO:1990599	level-07	depth-08	3' overhang single-stranded DNA endodeoxyribonuclease activity [molecular_function]
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000015': GOTerm('GO:0000015'):
#    id:GO:0000015
#    item_id:GO:0000015
#    name:phosphopyruvate hydratase complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:1902494
#    parents: 1 items
#      GO:1902494	level-02	depth-02	catalytic complex [cellular_component]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000016': GOTerm('GO:0000016'):
#    id:GO:0000016
#    item_id:GO:0000016
#    name:lactase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0004553
#    parents: 1 items
#      GO:0004553	level-04	depth-04	hydrolase activity, hydrolyzing O-glycosyl compounds [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000017': GOTerm('GO:0000017'):
#    id:GO:0000017
#    item_id:GO:0000017
#    name:alpha-glucoside transport
#    namespace:biological_process
#    _parents: 1 items
#      GO:0042946
#    parents: 1 items
#      GO:0042946	level-07	depth-07	glucoside transport [biological_process]
#    children: 0 items
#    level:8
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000018': GOTerm('GO:0000018'):
#    id:GO:0000018
#    item_id:GO:0000018
#    name:regulation of DNA recombination
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051052
#    parents: 1 items
#      GO:0051052	level-05	depth-06	regulation of DNA metabolic process [biological_process]
#    children: 10 items
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000019': GOTerm('GO:0000019'):
#    id:GO:0000019
#    item_id:GO:0000019
#    name:regulation of mitotic recombination
#    namespace:biological_process
#    _parents: 1 items
#      GO:0000018
#    parents: 1 items
#      GO:0000018	level-06	depth-07	regulation of DNA recombination [biological_process]
#    children: 4 items
#      GO:0045951	level-08	depth-09	positive regulation of mitotic recombination [biological_process]
#      GO:1903221	level-06	depth-09	regulation of mitotic recombination involved in replication fork processing [biological_process]
#      GO:0032207	level-07	depth-09	regulation of telomere maintenance via recombination [biological_process]
#      GO:0045950	level-08	depth-09	negative regulation of mitotic recombination [biological_process]
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000022': GOTerm('GO:0000022'):
#    id:GO:0000022
#    item_id:GO:0000022
#    name:mitotic spindle elongation
#    namespace:biological_process
#    _parents: 2 items
#      GO:0051231
#      GO:1903047
#    parents: 2 items
#      GO:0051231	level-03	depth-03	spindle elongation [biological_process]
#      GO:1903047	level-03	depth-03	mitotic cell cycle process [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:1905121,
#  'GO:0000023': GOTerm('GO:0000023'):
#    id:GO:0000023
#    item_id:GO:0000023
#    name:maltose metabolic process
#    namespace:biological_process
#    _parents: 1 items
#      GO:0005984
#    parents: 1 items
#      GO:0005984	level-04	depth-05	disaccharide metabolic process [biological_process]
#    children: 2 items
#      GO:0000025	level-06	depth-07	maltose catabolic process [biological_process]
#      GO:0000024	level-06	depth-07	maltose biosynthetic process [biological_process]
#    level:5
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000024': GOTerm('GO:0000024'):
#    id:GO:0000024
#    item_id:GO:0000024
#    name:maltose biosynthetic process
#    namespace:biological_process
#    _parents: 2 items
#      GO:0000023
#      GO:0046351
#    parents: 2 items
#      GO:0046351	level-05	depth-06	disaccharide biosynthetic process [biological_process]
#      GO:0000023	level-05	depth-06	maltose metabolic process [biological_process]
#    children: 0 items
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000025': GOTerm('GO:0000025'):
#    id:GO:0000025
#    item_id:GO:0000025
#    name:maltose catabolic process
#    namespace:biological_process
#    _parents: 2 items
#      GO:0000023
#      GO:0046352
#    parents: 2 items
#      GO:0046352	level-05	depth-06	disaccharide catabolic process [biological_process]
#      GO:0000023	level-05	depth-06	maltose metabolic process [biological_process]
#    children: 0 items
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000026': GOTerm('GO:0000026'):
#    id:GO:0000026
#    item_id:GO:0000026
#    name:alpha-1,2-mannosyltransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0000030
#    parents: 1 items
#      GO:0000030	level-05	depth-05	mannosyltransferase activity [molecular_function]
#    children: 3 items
#      GO:0004377	level-07	depth-07	GDP-Man:Man3GlcNAc2-PP-Dol alpha-1,2-mannosyltransferase activity [molecular_function]
#      GO:0052918	level-07	depth-07	dol-P-Man:Man(8)GlcNAc(2)-PP-Dol alpha-1,2-mannosyltransferase activity [molecular_function]
#      GO:0052926	level-07	depth-07	dol-P-Man:Man(6)GlcNAc(2)-PP-Dol alpha-1,2-mannosyltransferase activity [molecular_function]
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000027': GOTerm('GO:0000027'):
#    id:GO:0000027
#    item_id:GO:0000027
#    name:ribosomal large subunit assembly
#    namespace:biological_process
#    _parents: 1 items
#      GO:0022618
#    parents: 1 items
#      GO:0022618	level-06	depth-07	ribonucleoprotein complex assembly [biological_process]
#    children: 1 items
#      GO:1902775	level-08	depth-09	mitochondrial large ribosomal subunit assembly [biological_process]
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000028': GOTerm('GO:0000028'):
#    id:GO:0000028
#    item_id:GO:0000028
#    name:ribosomal small subunit assembly
#    namespace:biological_process
#    _parents: 1 items
#      GO:0022618
#    parents: 1 items
#      GO:0022618	level-06	depth-07	ribonucleoprotein complex assembly [biological_process]
#    children: 0 items
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000030': GOTerm('GO:0000030'):
#    id:GO:0000030
#    item_id:GO:0000030
#    name:mannosyltransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016758
#    parents: 1 items
#      GO:0016758	level-04	depth-04	hexosyltransferase activity [molecular_function]
#    children: 12 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000031': GOTerm('GO:0000031'):
#    id:GO:0000031
#    item_id:GO:0000031
#    name:mannosylphosphate transferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016758
#    parents: 1 items
#      GO:0016758	level-04	depth-04	hexosyltransferase activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000032': GOTerm('GO:0000032'):
#    id:GO:0000032
#    item_id:GO:0000032
#    name:cell wall mannoprotein biosynthetic process
#    namespace:biological_process
#    _parents: 2 items
#      GO:0006057
#      GO:0031506
#    parents: 2 items
#      GO:0006057	level-06	depth-07	mannoprotein biosynthetic process [biological_process]
#      GO:0031506	level-06	depth-08	cell wall glycoprotein biosynthetic process [biological_process]
#    children: 0 items
#    level:7
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000033': GOTerm('GO:0000033'):
#    id:GO:0000033
#    item_id:GO:0000033
#    name:alpha-1,3-mannosyltransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0000030
#    parents: 1 items
#      GO:0000030	level-05	depth-05	mannosyltransferase activity [molecular_function]
#    children: 1 items
#      GO:0052925	level-07	depth-07	dol-P-Man:Man(5)GlcNAc(2)-PP-Dol alpha-1,3-mannosyltransferase activity [molecular_function]
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000034': GOTerm('GO:0000034'):
#    id:GO:0000034
#    item_id:GO:0000034
#    name:adenine deaminase activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0019239
#      GO:0016814
#    parents: 2 items
#      GO:0016814	level-04	depth-04	hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds, in cyclic amidines [molecular_function]
#      GO:0019239	level-03	depth-03	deaminase activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000035': GOTerm('GO:0000035'):
#    id:GO:0000035
#    item_id:GO:0000035
#    name:acyl binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005488
#    parents: 1 items
#      GO:0005488	level-01	depth-01	binding [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000036': GOTerm('GO:0000036'):
#    id:GO:0000036
#    item_id:GO:0000036
#    name:acyl carrier activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0044620
#      GO:0140414
#    parents: 2 items
#      GO:0044620	level-03	depth-03	ACP phosphopantetheine attachment site binding [molecular_function]
#      GO:0140414	level-02	depth-02	phosphopantetheine-dependent carrier activity [molecular_function]
#    children: 0 items
#    level:3
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000038': GOTerm('GO:0000038'):
#    id:GO:0000038
#    item_id:GO:0000038
#    name:very long-chain fatty acid metabolic process
#    namespace:biological_process
#    _parents: 1 items
#      GO:0006631
#    parents: 1 items
#      GO:0006631	level-04	depth-07	fatty acid metabolic process [biological_process]
#    children: 2 items
#      GO:0042761	level-06	depth-09	very long-chain fatty acid biosynthetic process [biological_process]
#      GO:0042760	level-06	depth-09	very long-chain fatty acid catabolic process [biological_process]
#    level:5
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000041': GOTerm('GO:0000041'):
#    id:GO:0000041
#    item_id:GO:0000041
#    name:transition metal ion transport
#    namespace:biological_process
#    _parents: 1 items
#      GO:0006812
#    parents: 1 items
#      GO:0006812	level-05	depth-05	cation transport [biological_process]
#    children: 11 items
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000045': GOTerm('GO:0000045'):
#    id:GO:0000045
#    item_id:GO:0000045
#    name:autophagosome assembly
#    namespace:biological_process
#    _parents: 2 items
#      GO:1905037
#      GO:0070925
#    parents: 2 items
#      GO:0070925	level-05	depth-05	organelle assembly [biological_process]
#      GO:1905037	level-06	depth-06	autophagosome organization [biological_process]
#    children: 0 items
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000048': GOTerm('GO:0000048'):
#    id:GO:0000048
#    item_id:GO:0000048
#    name:peptidyltransferase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016755
#    parents: 1 items
#      GO:0016755	level-03	depth-04	aminoacyltransferase activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000049': GOTerm('GO:0000049'):
#    id:GO:0000049
#    item_id:GO:0000049
#    name:tRNA binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0003723
#    parents: 1 items
#      GO:0003723	level-04	depth-04	RNA binding [molecular_function]
#    children: 2 items
#      GO:0030557	level-06	depth-06	tRNA modification guide activity [molecular_function]
#      GO:1990856	level-06	depth-06	methionyl-initiator methionine tRNA binding [molecular_function]
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0000946,
#  'GO:0000050': GOTerm('GO:0000050'):
#    id:GO:0000050
#    item_id:GO:0000050
#    name:urea cycle
#    namespace:biological_process
#    _parents: 3 items
#      GO:0043604
#      GO:1901566
#      GO:0019627
#    parents: 3 items
#      GO:0019627	level-03	depth-05	urea metabolic process [biological_process]
#      GO:0043604	level-05	depth-05	amide biosynthetic process [biological_process]
#      GO:1901566	level-04	depth-04	organonitrogen compound biosynthetic process [biological_process]
#    children: 0 items
#    level:4
#    depth:6
#    is_obsolete:False
#    alt_ids: 2 items
#      GO:0006871
#      GO:0006594,
#  'GO:0000052': GOTerm('GO:0000052'):
#    id:GO:0000052
#    item_id:GO:0000052
#    name:citrulline metabolic process
#    namespace:biological_process
#    _parents: 1 items
#      GO:1901605
#    parents: 1 items
#      GO:1901605	level-04	depth-07	alpha-amino acid metabolic process [biological_process]
#    children: 2 items
#      GO:0019240	level-06	depth-09	citrulline biosynthetic process [biological_process]
#      GO:0019241	level-05	depth-09	citrulline catabolic process [biological_process]
#    level:5
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000053': GOTerm('GO:0000053'):
#    id:GO:0000053
#    item_id:GO:0000053
#    name:argininosuccinate metabolic process
#    namespace:biological_process
#    _parents: 3 items
#      GO:0006575
#      GO:1901605
#      GO:0072350
#    parents: 3 items
#      GO:0072350	level-06	depth-06	tricarboxylic acid metabolic process [biological_process]
#      GO:1901605	level-04	depth-07	alpha-amino acid metabolic process [biological_process]
#      GO:0006575	level-03	depth-04	cellular modified amino acid metabolic process [biological_process]
#    children: 0 items
#    level:4
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000054': GOTerm('GO:0000054'):
#    id:GO:0000054
#    item_id:GO:0000054
#    name:ribosomal subunit export from nucleus
#    namespace:biological_process
#    _parents: 3 items
#      GO:0033750
#      GO:0051656
#      GO:0071428
#    parents: 3 items
#      GO:0071428	level-04	depth-09	rRNA-containing ribonucleoprotein complex export from nucleus [biological_process]
#      GO:0051656	level-03	depth-04	establishment of organelle localization [biological_process]
#      GO:0033750	level-04	depth-04	ribosome localization [biological_process]
#    children: 2 items
#      GO:0000055	level-05	depth-11	ribosomal large subunit export from nucleus [biological_process]
#      GO:0000056	level-05	depth-11	ribosomal small subunit export from nucleus [biological_process]
#    level:4
#    depth:10
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000055': GOTerm('GO:0000055'):
#    id:GO:0000055
#    item_id:GO:0000055
#    name:ribosomal large subunit export from nucleus
#    namespace:biological_process
#    _parents: 1 items
#      GO:0000054
#    parents: 1 items
#      GO:0000054	level-04	depth-10	ribosomal subunit export from nucleus [biological_process]
#    children: 0 items
#    level:5
#    depth:11
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0000057,
#  'GO:0000056': GOTerm('GO:0000056'):
#    id:GO:0000056
#    item_id:GO:0000056
#    name:ribosomal small subunit export from nucleus
#    namespace:biological_process
#    _parents: 1 items
#      GO:0000054
#    parents: 1 items
#      GO:0000054	level-04	depth-10	ribosomal subunit export from nucleus [biological_process]
#    children: 0 items
#    level:5
#    depth:11
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0000058,
#  'GO:0000062': GOTerm('GO:0000062'):
#    id:GO:0000062
#    item_id:GO:0000062
#    name:fatty-acyl-CoA binding
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0120227
#      GO:1901567
#    parents: 2 items
#      GO:0120227	level-03	depth-08	acyl-CoA binding [molecular_function]
#      GO:1901567	level-02	depth-02	fatty acid derivative binding [molecular_function]
#    children: 1 items
#      GO:0036042	level-04	depth-10	long-chain fatty acyl-CoA binding [molecular_function]
#    level:3
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000064': GOTerm('GO:0000064'):
#    id:GO:0000064
#    item_id:GO:0000064
#    name:L-ornithine transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 3 items
#      GO:0015179
#      GO:0008324
#      GO:0008514
#    parents: 3 items
#      GO:0008324	level-04	depth-04	cation transmembrane transporter activity [molecular_function]
#      GO:0015179	level-06	depth-06	L-amino acid transmembrane transporter activity [molecular_function]
#      GO:0008514	level-05	depth-05	organic anion transmembrane transporter activity [molecular_function]
#    children: 2 items
#      GO:0097627	level-06	depth-08	high-affinity L-ornithine transmembrane transporter activity [molecular_function]
#      GO:0015496	level-05	depth-08	putrescine:ornithine antiporter activity [molecular_function]
#    level:5
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000070': GOTerm('GO:0000070'):
#    id:GO:0000070
#    item_id:GO:0000070
#    name:mitotic sister chromatid segregation
#    namespace:biological_process
#    _parents: 2 items
#      GO:0000819
#      GO:1903047
#    parents: 2 items
#      GO:0000819	level-04	depth-06	sister chromatid segregation [biological_process]
#      GO:1903047	level-03	depth-03	mitotic cell cycle process [biological_process]
#    children: 0 items
#    level:4
#    depth:7
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0016359,
#  'GO:0000073': GOTerm('GO:0000073'):
#    id:GO:0000073
#    item_id:GO:0000073
#    name:initial mitotic spindle pole body separation
#    namespace:biological_process
#    _parents: 2 items
#      GO:0110100
#      GO:1903047
#    parents: 2 items
#      GO:0110100	level-03	depth-03	spindle pole body separation [biological_process]
#      GO:1903047	level-03	depth-03	mitotic cell cycle process [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0030475,
#  'GO:0000075': GOTerm('GO:0000075'):
#    id:GO:0000075
#    item_id:GO:0000075
#    name:cell cycle checkpoint signaling
#    namespace:biological_process
#    _parents: 2 items
#      GO:0035556
#      GO:1901988
#    parents: 2 items
#      GO:1901988	level-07	depth-07	negative regulation of cell cycle phase transition [biological_process]
#      GO:0035556	level-03	depth-05	intracellular signal transduction [biological_process]
#    children: 4 items
#      GO:0031570	level-05	depth-09	DNA integrity checkpoint signaling [biological_process]
#      GO:0031577	level-05	depth-09	spindle checkpoint signaling [biological_process]
#      GO:0033313	level-03	depth-09	meiotic cell cycle checkpoint signaling [biological_process]
#      GO:0007093	level-04	depth-09	mitotic cell cycle checkpoint signaling [biological_process]
#    level:4
#    depth:8
#    is_obsolete:False
#    alt_ids: 5 items
#      GO:0072404
#      GO:0031576
#      GO:0071779
#      GO:0072407
#      GO:0072395,
#  'GO:0000076': GOTerm('GO:0000076'):
#    id:GO:0000076
#    item_id:GO:0000076
#    name:DNA replication checkpoint signaling
#    namespace:biological_process
#    _parents: 1 items
#      GO:0031570
#    parents: 1 items
#      GO:0031570	level-05	depth-09	DNA integrity checkpoint signaling [biological_process]
#    children: 2 items
#      GO:0033315	level-05	depth-11	meiotic G2/MI DNA replication checkpoint signaling [biological_process]
#      GO:0033314	level-06	depth-11	mitotic DNA replication checkpoint signaling [biological_process]
#    level:6
#    depth:10
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0072437,
#  'GO:0000077': GOTerm('GO:0000077'):
#    id:GO:0000077
#    item_id:GO:0000077
#    name:DNA damage checkpoint signaling
#    namespace:biological_process
#    _parents: 2 items
#      GO:0031570
#      GO:0042770
#    parents: 2 items
#      GO:0031570	level-05	depth-09	DNA integrity checkpoint signaling [biological_process]
#      GO:0042770	level-04	depth-06	signal transduction in response to DNA damage [biological_process]
#    children: 1 items
#      GO:0044773	level-06	depth-11	mitotic DNA damage checkpoint signaling [biological_process]
#    level:5
#    depth:10
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0072422,
#  'GO:0000079': GOTerm('GO:0000079'):
#    id:GO:0000079
#    item_id:GO:0000079
#    name:regulation of cyclin-dependent protein serine/threonine kinase activity
#    namespace:biological_process
#    _parents: 2 items
#      GO:0071900
#      GO:1904029
#    parents: 2 items
#      GO:0071900	level-07	depth-10	regulation of protein serine/threonine kinase activity [biological_process]
#      GO:1904029	level-05	depth-10	regulation of cyclin-dependent protein kinase activity [biological_process]
#    children: 2 items
#      GO:0045736	level-06	depth-12	negative regulation of cyclin-dependent protein serine/threonine kinase activity [biological_process]
#      GO:0045737	level-06	depth-12	positive regulation of cyclin-dependent protein serine/threonine kinase activity [biological_process]
#    level:6
#    depth:11
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000080': GOTerm('GO:0000080'):
#    id:GO:0000080
#    item_id:GO:0000080
#    name:mitotic G1 phase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051318
#    parents: 1 items
#      GO:0051318	level-03	depth-03	G1 phase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000082': GOTerm('GO:0000082'):
#    id:GO:0000082
#    item_id:GO:0000082
#    name:G1/S transition of mitotic cell cycle
#    namespace:biological_process
#    _parents: 2 items
#      GO:0044772
#      GO:0044843
#    parents: 2 items
#      GO:0044772	level-04	depth-04	mitotic cell cycle phase transition [biological_process]
#      GO:0044843	level-04	depth-04	cell cycle G1/S phase transition [biological_process]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000083': GOTerm('GO:0000083'):
#    id:GO:0000083
#    item_id:GO:0000083
#    name:regulation of transcription involved in G1/S transition of mitotic cell cycle
#    namespace:biological_process
#    _parents: 2 items
#      GO:0006355
#      GO:1903047
#    parents: 2 items
#      GO:1903047	level-03	depth-03	mitotic cell cycle process [biological_process]
#      GO:0006355	level-06	depth-09	regulation of transcription, DNA-templated [biological_process]
#    children: 2 items
#      GO:0071931	level-05	depth-11	positive regulation of transcription involved in G1/S transition of mitotic cell cycle [biological_process]
#      GO:0071930	level-05	depth-11	negative regulation of transcription involved in G1/S transition of mitotic cell cycle [biological_process]
#    level:4
#    depth:10
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000084': GOTerm('GO:0000084'):
#    id:GO:0000084
#    item_id:GO:0000084
#    name:mitotic S phase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051320
#    parents: 1 items
#      GO:0051320	level-03	depth-03	S phase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000085': GOTerm('GO:0000085'):
#    id:GO:0000085
#    item_id:GO:0000085
#    name:mitotic G2 phase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051319
#    parents: 1 items
#      GO:0051319	level-03	depth-03	G2 phase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000086': GOTerm('GO:0000086'):
#    id:GO:0000086
#    item_id:GO:0000086
#    name:G2/M transition of mitotic cell cycle
#    namespace:biological_process
#    _parents: 2 items
#      GO:0044772
#      GO:0044839
#    parents: 2 items
#      GO:0044772	level-04	depth-04	mitotic cell cycle phase transition [biological_process]
#      GO:0044839	level-04	depth-04	cell cycle G2/M phase transition [biological_process]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000087': GOTerm('GO:0000087'):
#    id:GO:0000087
#    item_id:GO:0000087
#    name:mitotic M phase
#    namespace:biological_process
#    _parents: 2 items
#      GO:0000279
#      GO:0098763
#    parents: 2 items
#      GO:0098763	level-03	depth-03	mitotic cell cycle phase [biological_process]
#      GO:0000279	level-03	depth-03	M phase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000088': GOTerm('GO:0000088'):
#    id:GO:0000088
#    item_id:GO:0000088
#    name:mitotic prophase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051324
#    parents: 1 items
#      GO:0051324	level-03	depth-03	prophase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000089': GOTerm('GO:0000089'):
#    id:GO:0000089
#    item_id:GO:0000089
#    name:mitotic metaphase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051323
#    parents: 1 items
#      GO:0051323	level-03	depth-03	metaphase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000090': GOTerm('GO:0000090'):
#    id:GO:0000090
#    item_id:GO:0000090
#    name:mitotic anaphase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051322
#    parents: 1 items
#      GO:0051322	level-03	depth-03	anaphase [biological_process]
#    children: 2 items
#      GO:0000091	level-05	depth-05	mitotic anaphase A [biological_process]
#      GO:0000092	level-05	depth-05	mitotic anaphase B [biological_process]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000091': GOTerm('GO:0000091'):
#    id:GO:0000091
#    item_id:GO:0000091
#    name:mitotic anaphase A
#    namespace:biological_process
#    _parents: 1 items
#      GO:0000090
#    parents: 1 items
#      GO:0000090	level-04	depth-04	mitotic anaphase [biological_process]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000092': GOTerm('GO:0000092'):
#    id:GO:0000092
#    item_id:GO:0000092
#    name:mitotic anaphase B
#    namespace:biological_process
#    _parents: 1 items
#      GO:0000090
#    parents: 1 items
#      GO:0000090	level-04	depth-04	mitotic anaphase [biological_process]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000093': GOTerm('GO:0000093'):
#    id:GO:0000093
#    item_id:GO:0000093
#    name:mitotic telophase
#    namespace:biological_process
#    _parents: 1 items
#      GO:0051326
#    parents: 1 items
#      GO:0051326	level-03	depth-03	telophase [biological_process]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000095': GOTerm('GO:0000095'):
#    id:GO:0000095
#    item_id:GO:0000095
#    name:S-adenosyl-L-methionine transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:1901682
#      GO:0015101
#    parents: 2 items
#      GO:0015101	level-05	depth-05	organic cation transmembrane transporter activity [molecular_function]
#      GO:1901682	level-03	depth-03	sulfur compound transmembrane transporter activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:6
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0015177,
#  'GO:0000096': GOTerm('GO:0000096'):
#    id:GO:0000096
#    item_id:GO:0000096
#    name:sulfur amino acid metabolic process
#    namespace:biological_process
#    _parents: 3 items
#      GO:1901564
#      GO:0006790
#      GO:0006082
#    parents: 3 items
#      GO:0006082	level-03	depth-03	organic acid metabolic process [biological_process]
#      GO:1901564	level-03	depth-03	organonitrogen compound metabolic process [biological_process]
#      GO:0006790	level-03	depth-03	sulfur compound metabolic process [biological_process]
#    children: 6 items
#      GO:0000097	level-05	depth-05	sulfur amino acid biosynthetic process [biological_process]
#      GO:0000098	level-05	depth-05	sulfur amino acid catabolic process [biological_process]
#      GO:0050667	level-05	depth-08	homocysteine metabolic process [biological_process]
#      GO:0052698	level-05	depth-06	ergothioneine metabolic process [biological_process]
#      GO:0006555	level-05	depth-09	methionine metabolic process [biological_process]
#      GO:0006534	level-05	depth-09	cysteine metabolic process [biological_process]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000097': GOTerm('GO:0000097'):
#    id:GO:0000097
#    item_id:GO:0000097
#    name:sulfur amino acid biosynthetic process
#    namespace:biological_process
#    _parents: 4 items
#      GO:0044272
#      GO:1901566
#      GO:0000096
#      GO:0016053
#    parents: 4 items
#      GO:0016053	level-04	depth-04	organic acid biosynthetic process [biological_process]
#      GO:0000096	level-04	depth-04	sulfur amino acid metabolic process [biological_process]
#      GO:1901566	level-04	depth-04	organonitrogen compound biosynthetic process [biological_process]
#      GO:0044272	level-04	depth-04	sulfur compound biosynthetic process [biological_process]
#    children: 4 items
#      GO:0019344	level-06	depth-10	cysteine biosynthetic process [biological_process]
#      GO:0052699	level-06	depth-07	ergothioneine biosynthetic process [biological_process]
#      GO:0009086	level-06	depth-10	methionine biosynthetic process [biological_process]
#      GO:0071268	level-06	depth-09	homocysteine biosynthetic process [biological_process]
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000098': GOTerm('GO:0000098'):
#    id:GO:0000098
#    item_id:GO:0000098
#    name:sulfur amino acid catabolic process
#    namespace:biological_process
#    _parents: 4 items
#      GO:1901565
#      GO:0044273
#      GO:0016054
#      GO:0000096
#    parents: 4 items
#      GO:0000096	level-04	depth-04	sulfur amino acid metabolic process [biological_process]
#      GO:0044273	level-04	depth-04	sulfur compound catabolic process [biological_process]
#      GO:1901565	level-04	depth-04	organonitrogen compound catabolic process [biological_process]
#      GO:0016054	level-04	depth-04	organic acid catabolic process [biological_process]
#    children: 4 items
#      GO:0052700	level-06	depth-07	ergothioneine catabolic process [biological_process]
#      GO:0009087	level-05	depth-10	methionine catabolic process [biological_process]
#      GO:0043418	level-05	depth-09	homocysteine catabolic process [biological_process]
#      GO:0009093	level-05	depth-10	cysteine catabolic process [biological_process]
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000099': GOTerm('GO:0000099'):
#    id:GO:0000099
#    item_id:GO:0000099
#    name:sulfur amino acid transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0015171
#      GO:1901682
#    parents: 2 items
#      GO:0015171	level-05	depth-05	amino acid transmembrane transporter activity [molecular_function]
#      GO:1901682	level-03	depth-03	sulfur compound transmembrane transporter activity [molecular_function]
#    children: 4 items
#      GO:1901680	level-05	depth-07	sulfur-containing amino acid secondary active transmembrane transporter activity [molecular_function]
#      GO:0043865	level-05	depth-07	methionine transmembrane transporter activity [molecular_function]
#      GO:0033229	level-05	depth-07	cysteine transmembrane transporter activity [molecular_function]
#      GO:0015184	level-04	depth-07	L-cystine transmembrane transporter activity [molecular_function]
#    level:4
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000100': GOTerm('GO:0000100'):
#    id:GO:0000100
#    item_id:GO:0000100
#    name:S-methylmethionine transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0072349
#      GO:1901682
#    parents: 2 items
#      GO:0072349	level-03	depth-03	modified amino acid transmembrane transporter activity [molecular_function]
#      GO:1901682	level-03	depth-03	sulfur compound transmembrane transporter activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0015178,
#  'GO:0000101': GOTerm('GO:0000101'):
#    id:GO:0000101
#    item_id:GO:0000101
#    name:sulfur amino acid transport
#    namespace:biological_process
#    _parents: 2 items
#      GO:0006865
#      GO:0072348
#    parents: 2 items
#      GO:0072348	level-04	depth-04	sulfur compound transport [biological_process]
#      GO:0006865	level-05	depth-06	amino acid transport [biological_process]
#    children: 3 items
#      GO:0042883	level-06	depth-08	cysteine transport [biological_process]
#      GO:0015811	level-06	depth-09	L-cystine transport [biological_process]
#      GO:0015821	level-06	depth-08	methionine transport [biological_process]
#    level:5
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000102': GOTerm('GO:0000102'):
#    id:GO:0000102
#    item_id:GO:0000102
#    name:L-methionine secondary active transmembrane transporter activity
#    namespace:molecular_function
#    _parents: 4 items
#      GO:0022853
#      GO:1901680
#      GO:0005294
#      GO:0015191
#    parents: 4 items
#      GO:1901680	level-05	depth-07	sulfur-containing amino acid secondary active transmembrane transporter activity [molecular_function]
#      GO:0015191	level-06	depth-08	L-methionine transmembrane transporter activity [molecular_function]
#      GO:0005294	level-05	depth-07	neutral L-amino acid secondary active transmembrane transporter activity [molecular_function]
#      GO:0022853	level-04	depth-04	active ion transmembrane transporter activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000103': GOTerm('GO:0000103'):
#    id:GO:0000103
#    item_id:GO:0000103
#    name:sulfate assimilation
#    namespace:biological_process
#    _parents: 1 items
#      GO:0006790
#    parents: 1 items
#      GO:0006790	level-03	depth-03	sulfur compound metabolic process [biological_process]
#    children: 2 items
#      GO:0010134	level-05	depth-05	sulfate assimilation via adenylyl sulfate reduction [biological_process]
#      GO:0019379	level-05	depth-05	sulfate assimilation, phosphoadenylyl sulfate reduction by phosphoadenylyl-sulfate reductase (thioredoxin) [biological_process]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0019378,
#  'GO:0000104': GOTerm('GO:0000104'):
#    id:GO:0000104
#    item_id:GO:0000104
#    name:succinate dehydrogenase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016627
#    parents: 1 items
#      GO:0016627	level-03	depth-03	oxidoreductase activity, acting on the CH-CH group of donors [molecular_function]
#    children: 1 items
#      GO:0008177	level-05	depth-05	succinate dehydrogenase (ubiquinone) activity [molecular_function]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0019739,
#  'GO:0000105': GOTerm('GO:0000105'):
#    id:GO:0000105
#    item_id:GO:0000105
#    name:histidine biosynthetic process
#    namespace:biological_process
#    _parents: 2 items
#      GO:0008652
#      GO:0006547
#    parents: 2 items
#      GO:0006547	level-04	depth-07	histidine metabolic process [biological_process]
#      GO:0008652	level-04	depth-07	cellular amino acid biosynthetic process [biological_process]
#    children: 0 items
#    level:5
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000107': GOTerm('GO:0000107'):
#    id:GO:0000107
#    item_id:GO:0000107
#    name:imidazoleglycerol-phosphate synthase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016763
#    parents: 1 items
#      GO:0016763	level-04	depth-04	pentosyltransferase activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000109': GOTerm('GO:0000109'):
#    id:GO:0000109
#    item_id:GO:0000109
#    name:nucleotide-excision repair complex
#    namespace:cellular_component
#    _parents: 2 items
#      GO:1990391
#      GO:0140513
#    parents: 2 items
#      GO:1990391	level-02	depth-02	DNA repair complex [cellular_component]
#      GO:0140513	level-02	depth-02	nuclear protein-containing complex [cellular_component]
#    children: 9 items
#      GO:0000110	level-04	depth-04	nucleotide-excision repair factor 1 complex [cellular_component]
#      GO:0071942	level-04	depth-04	XPC complex [cellular_component]
#      GO:0000111	level-04	depth-04	nucleotide-excision repair factor 2 complex [cellular_component]
#      GO:0070912	level-04	depth-04	Ddb1-Ckn1 complex [cellular_component]
#      GO:0000112	level-04	depth-04	nucleotide-excision repair factor 3 complex [cellular_component]
#      GO:0070913	level-04	depth-04	Ddb1-Wdr21 complex [cellular_component]
#      GO:0000113	level-04	depth-04	nucleotide-excision repair factor 4 complex [cellular_component]
#      GO:0070522	level-04	depth-04	ERCC4-ERCC1 complex [cellular_component]
#      GO:0070312	level-04	depth-04	RAD52-ERCC4-ERCC1 complex [cellular_component]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000110': GOTerm('GO:0000110'):
#    id:GO:0000110
#    item_id:GO:0000110
#    name:nucleotide-excision repair factor 1 complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0000109
#    parents: 1 items
#      GO:0000109	level-03	depth-03	nucleotide-excision repair complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000111': GOTerm('GO:0000111'):
#    id:GO:0000111
#    item_id:GO:0000111
#    name:nucleotide-excision repair factor 2 complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0000109
#    parents: 1 items
#      GO:0000109	level-03	depth-03	nucleotide-excision repair complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000112': GOTerm('GO:0000112'):
#    id:GO:0000112
#    item_id:GO:0000112
#    name:nucleotide-excision repair factor 3 complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0000109
#    parents: 1 items
#      GO:0000109	level-03	depth-03	nucleotide-excision repair complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000113': GOTerm('GO:0000113'):
#    id:GO:0000113
#    item_id:GO:0000113
#    name:nucleotide-excision repair factor 4 complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0000109
#    parents: 1 items
#      GO:0000109	level-03	depth-03	nucleotide-excision repair complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000117': GOTerm('GO:0000117'):
#    id:GO:0000117
#    item_id:GO:0000117
#    name:regulation of transcription involved in G2/M transition of mitotic cell cycle
#    namespace:biological_process
#    _parents: 2 items
#      GO:0006355
#      GO:1903047
#    parents: 2 items
#      GO:1903047	level-03	depth-03	mitotic cell cycle process [biological_process]
#      GO:0006355	level-06	depth-09	regulation of transcription, DNA-templated [biological_process]
#    children: 2 items
#      GO:0090419	level-05	depth-11	negative regulation of transcription involved in G2/M transition of mitotic cell cycle [biological_process]
#      GO:0090282	level-05	depth-12	positive regulation of transcription involved in G2/M transition of mitotic cell cycle [biological_process]
#    level:4
#    depth:10
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000118': GOTerm('GO:0000118'):
#    id:GO:0000118
#    item_id:GO:0000118
#    name:histone deacetylase complex
#    namespace:cellular_component
#    _parents: 2 items
#      GO:1902494
#      GO:0140513
#    parents: 2 items
#      GO:1902494	level-02	depth-02	catalytic complex [cellular_component]
#      GO:0140513	level-02	depth-02	nuclear protein-containing complex [cellular_component]
#    children: 10 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000120': GOTerm('GO:0000120'):
#    id:GO:0000120
#    item_id:GO:0000120
#    name:RNA polymerase I transcription regulator complex
#    namespace:cellular_component
#    _parents: 2 items
#      GO:0005667
#      GO:0140513
#    parents: 2 items
#      GO:0005667	level-02	depth-02	transcription regulator complex [cellular_component]
#      GO:0140513	level-02	depth-02	nuclear protein-containing complex [cellular_component]
#    children: 3 items
#      GO:0000500	level-04	depth-04	RNA polymerase I upstream activating factor complex [cellular_component]
#      GO:0070860	level-04	depth-04	RNA polymerase I core factor complex [cellular_component]
#      GO:0005668	level-04	depth-04	RNA polymerase transcription factor SL1 complex [cellular_component]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000121': GOTerm('GO:0000121'):
#    id:GO:0000121
#    item_id:GO:0000121
#    name:glycerol-1-phosphatase activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0016791
#    parents: 1 items
#      GO:0016791	level-05	depth-05	phosphatase activity [molecular_function]
#    children: 0 items
#    level:6
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000122': GOTerm('GO:0000122'):
#    id:GO:0000122
#    item_id:GO:0000122
#    name:negative regulation of transcription by RNA polymerase II
#    namespace:biological_process
#    _parents: 2 items
#      GO:0045892
#      GO:0006357
#    parents: 2 items
#      GO:0045892	level-07	depth-10	negative regulation of transcription, DNA-templated [biological_process]
#      GO:0006357	level-07	depth-10	regulation of transcription by RNA polymerase II [biological_process]
#    children: 22 items
#    level:8
#    depth:11
#    is_obsolete:False
#    alt_ids: 2 items
#      GO:0010553
#      GO:0045816,
#  'GO:0000123': GOTerm('GO:0000123'):
#    id:GO:0000123
#    item_id:GO:0000123
#    name:histone acetyltransferase complex
#    namespace:cellular_component
#    _parents: 2 items
#      GO:0031248
#      GO:0140513
#    parents: 2 items
#      GO:0031248	level-03	depth-05	protein acetyltransferase complex [cellular_component]
#      GO:0140513	level-02	depth-02	nuclear protein-containing complex [cellular_component]
#    children: 3 items
#      GO:1902562	level-04	depth-07	H4 histone acetyltransferase complex [cellular_component]
#      GO:0070461	level-04	depth-07	SAGA-type complex [cellular_component]
#      GO:0070775	level-04	depth-07	H3 histone acetyltransferase complex [cellular_component]
#    level:3
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000124': GOTerm('GO:0000124'):
#    id:GO:0000124
#    item_id:GO:0000124
#    name:SAGA complex
#    namespace:cellular_component
#    _parents: 2 items
#      GO:1905368
#      GO:0070461
#    parents: 2 items
#      GO:0070461	level-04	depth-07	SAGA-type complex [cellular_component]
#      GO:1905368	level-03	depth-03	peptidase complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000125': GOTerm('GO:0000125'):
#    id:GO:0000125
#    item_id:GO:0000125
#    name:PCAF complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0070461
#    parents: 1 items
#      GO:0070461	level-04	depth-07	SAGA-type complex [cellular_component]
#    children: 0 items
#    level:5
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000126': GOTerm('GO:0000126'):
#    id:GO:0000126
#    item_id:GO:0000126
#    name:transcription factor TFIIIB complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0090576
#    parents: 1 items
#      GO:0090576	level-03	depth-03	RNA polymerase III transcription regulator complex [cellular_component]
#    children: 2 items
#      GO:0034732	level-05	depth-05	transcription factor TFIIIB-alpha complex [cellular_component]
#      GO:0034733	level-05	depth-05	transcription factor TFIIIB-beta complex [cellular_component]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000127': GOTerm('GO:0000127'):
#    id:GO:0000127
#    item_id:GO:0000127
#    name:transcription factor TFIIIC complex
#    namespace:cellular_component
#    _parents: 1 items
#      GO:0090576
#    parents: 1 items
#      GO:0090576	level-03	depth-03	RNA polymerase III transcription regulator complex [cellular_component]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0000128': GOTerm('GO:0000128'):
#    id:GO:0000128
#    item_id:GO:0000128
#    name:flocculation
#    namespace:biological_process
# ...
#    id:GO:0001850
#    item_id:GO:0001850
#    name:complement component C3a binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001848
#    parents: 1 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001851': GOTerm('GO:0001851'):
#    id:GO:0001851
#    item_id:GO:0001851
#    name:complement component C3b binding
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001846
#      GO:0001848
#    parents: 2 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#      GO:0001846	level-03	depth-03	opsonin binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001852': GOTerm('GO:0001852'):
#    id:GO:0001852
#    item_id:GO:0001852
#    name:complement component iC3b binding
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001846
#      GO:0001848
#    parents: 2 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#      GO:0001846	level-03	depth-03	opsonin binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001853': GOTerm('GO:0001853'):
#    id:GO:0001853
#    item_id:GO:0001853
#    name:complement component C3dg binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001848
#    parents: 1 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001854': GOTerm('GO:0001854'):
#    id:GO:0001854
#    item_id:GO:0001854
#    name:complement component C3d binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001848
#    parents: 1 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001855': GOTerm('GO:0001855'):
#    id:GO:0001855
#    item_id:GO:0001855
#    name:complement component C4b binding
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001846
#      GO:0001848
#    parents: 2 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#      GO:0001846	level-03	depth-03	opsonin binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001856': GOTerm('GO:0001856'):
#    id:GO:0001856
#    item_id:GO:0001856
#    name:complement component C5a binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001848
#    parents: 1 items
#      GO:0001848	level-03	depth-03	complement binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001857': GOTerm('GO:0001857'):
#    id:GO:0001857
#    item_id:GO:0001857
#    name:complement component C1q receptor activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001847
#      GO:0004875
#    parents: 2 items
#      GO:0001847	level-04	depth-04	opsonin receptor activity [molecular_function]
#      GO:0004875	level-04	depth-04	complement receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001858': GOTerm('GO:0001858'):
#    id:GO:0001858
#    item_id:GO:0001858
#    name:complement component iC3b receptor activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001847
#      GO:0004875
#    parents: 2 items
#      GO:0001847	level-04	depth-04	opsonin receptor activity [molecular_function]
#      GO:0004875	level-04	depth-04	complement receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001859': GOTerm('GO:0001859'):
#    id:GO:0001859
#    item_id:GO:0001859
#    name:complement component C3dg receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0004875
#    parents: 1 items
#      GO:0004875	level-04	depth-04	complement receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001860': GOTerm('GO:0001860'):
#    id:GO:0001860
#    item_id:GO:0001860
#    name:complement component C3d receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0004875
#    parents: 1 items
#      GO:0004875	level-04	depth-04	complement receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001861': GOTerm('GO:0001861'):
#    id:GO:0001861
#    item_id:GO:0001861
#    name:complement component C4b receptor activity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0001847
#      GO:0004875
#    parents: 2 items
#      GO:0001847	level-04	depth-04	opsonin receptor activity [molecular_function]
#      GO:0004875	level-04	depth-04	complement receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001862': GOTerm('GO:0001862'):
#    id:GO:0001862
#    item_id:GO:0001862
#    name:collectin binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001846
#    parents: 1 items
#      GO:0001846	level-03	depth-03	opsonin binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001863': GOTerm('GO:0001863'):
#    id:GO:0001863
#    item_id:GO:0001863
#    name:collectin receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001847
#    parents: 1 items
#      GO:0001847	level-04	depth-04	opsonin receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001864': GOTerm('GO:0001864'):
#    id:GO:0001864
#    item_id:GO:0001864
#    name:pentraxin binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001846
#    parents: 1 items
#      GO:0001846	level-03	depth-03	opsonin binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001865': GOTerm('GO:0001865'):
#    id:GO:0001865
#    item_id:GO:0001865
#    name:NK T cell differentiation
#    namespace:biological_process
#    _parents: 1 items
#      GO:0046632
#    parents: 1 items
#      GO:0046632	level-06	depth-08	alpha-beta T cell differentiation [biological_process]
#    children: 0 items
#    level:7
#    depth:9
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001866': GOTerm('GO:0001866'):
#    id:GO:0001866
#    item_id:GO:0001866
#    name:NK T cell proliferation
#    namespace:biological_process
#    _parents: 2 items
#      GO:0051132
#      GO:0046633
#    parents: 2 items
#      GO:0051132	level-06	depth-07	NK T cell activation [biological_process]
#      GO:0046633	level-06	depth-07	alpha-beta T cell proliferation [biological_process]
#    children: 1 items
#      GO:0002289	level-08	depth-09	NK T cell proliferation involved in immune response [biological_process]
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001867': GOTerm('GO:0001867'):
#    id:GO:0001867
#    item_id:GO:0001867
#    name:complement activation, lectin pathway
#    namespace:biological_process
#    _parents: 2 items
#      GO:0006956
#      GO:0045087
#    parents: 2 items
#      GO:0045087	level-04	depth-06	innate immune response [biological_process]
#      GO:0006956	level-03	depth-07	complement activation [biological_process]
#    children: 0 items
#    level:4
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001868': GOTerm('GO:0001868'):
#    id:GO:0001868
#    item_id:GO:0001868
#    name:regulation of complement activation, lectin pathway
#    namespace:biological_process
#    _parents: 2 items
#      GO:0045088
#      GO:0030449
#    parents: 2 items
#      GO:0030449	level-05	depth-06	regulation of complement activation [biological_process]
#      GO:0045088	level-05	depth-06	regulation of innate immune response [biological_process]
#    children: 3 items
#      GO:0044630	level-04	depth-08	modulation of complement activation, lectin pathway in other organism [biological_process]
#      GO:0001869	level-07	depth-08	negative regulation of complement activation, lectin pathway [biological_process]
#      GO:0001870	level-07	depth-08	positive regulation of complement activation, lectin pathway [biological_process]
#    level:6
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001869': GOTerm('GO:0001869'):
#    id:GO:0001869
#    item_id:GO:0001869
#    name:negative regulation of complement activation, lectin pathway
#    namespace:biological_process
#    _parents: 3 items
#      GO:0045824
#      GO:0045916
#      GO:0001868
#    parents: 3 items
#      GO:0001868	level-06	depth-07	regulation of complement activation, lectin pathway [biological_process]
#      GO:0045916	level-06	depth-07	negative regulation of complement activation [biological_process]
#      GO:0045824	level-06	depth-07	negative regulation of innate immune response [biological_process]
#    children: 1 items
#      GO:0044632	level-05	depth-09	negative regulation of complement activation, lectin pathway in other organism [biological_process]
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001870': GOTerm('GO:0001870'):
#    id:GO:0001870
#    item_id:GO:0001870
#    name:positive regulation of complement activation, lectin pathway
#    namespace:biological_process
#    _parents: 3 items
#      GO:0045917
#      GO:0045089
#      GO:0001868
#    parents: 3 items
#      GO:0045917	level-06	depth-07	positive regulation of complement activation [biological_process]
#      GO:0001868	level-06	depth-07	regulation of complement activation, lectin pathway [biological_process]
#      GO:0045089	level-06	depth-07	positive regulation of innate immune response [biological_process]
#    children: 1 items
#      GO:0044631	level-05	depth-09	positive regulation of complement activation, lectin pathway in other organism [biological_process]
#    level:7
#    depth:8
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001872': GOTerm('GO:0001872'):
#    id:GO:0001872
#    item_id:GO:0001872
#    name:(1->3)-beta-D-glucan binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0030247
#    parents: 1 items
#      GO:0030247	level-03	depth-03	polysaccharide binding [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0080087,
#  'GO:0001873': GOTerm('GO:0001873'):
#    id:GO:0001873
#    item_id:GO:0001873
#    name:polysaccharide immune receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0038187
#    parents: 1 items
#      GO:0038187	level-03	depth-03	pattern recognition receptor activity [molecular_function]
#    children: 1 items
#      GO:0001874	level-05	depth-05	(1->3)-beta-D-glucan immune receptor activity [molecular_function]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001874': GOTerm('GO:0001874'):
#    id:GO:0001874
#    item_id:GO:0001874
#    name:(1->3)-beta-D-glucan immune receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001873
#    parents: 1 items
#      GO:0001873	level-04	depth-04	polysaccharide immune receptor activity [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001875': GOTerm('GO:0001875'):
#    id:GO:0001875
#    item_id:GO:0001875
#    name:lipopolysaccharide immune receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0038187
#    parents: 1 items
#      GO:0038187	level-03	depth-03	pattern recognition receptor activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001876': GOTerm('GO:0001876'):
#    id:GO:0001876
#    item_id:GO:0001876
#    name:lipoarabinomannan binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0034235
#    parents: 1 items
#      GO:0034235	level-04	depth-05	GPI anchor binding [molecular_function]
#    children: 0 items
#    level:5
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001877': GOTerm('GO:0001877'):
#    id:GO:0001877
#    item_id:GO:0001877
#    name:lipoarabinomannan immune receptor activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0038187
#    parents: 1 items
#      GO:0038187	level-03	depth-03	pattern recognition receptor activity [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001878': GOTerm('GO:0001878'):
#    id:GO:0001878
#    item_id:GO:0001878
#    name:response to yeast
#    namespace:biological_process
#    _parents: 1 items
#      GO:0009620
#    parents: 1 items
#      GO:0009620	level-03	depth-05	response to fungus [biological_process]
#    children: 1 items
#      GO:0001879	level-05	depth-07	detection of yeast [biological_process]
#    level:4
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001879': GOTerm('GO:0001879'):
#    id:GO:0001879
#    item_id:GO:0001879
#    name:detection of yeast
#    namespace:biological_process
#    _parents: 2 items
#      GO:0001878
#      GO:0016046
#    parents: 2 items
#      GO:0001878	level-04	depth-06	response to yeast [biological_process]
#      GO:0016046	level-04	depth-06	detection of fungus [biological_process]
#    children: 0 items
#    level:5
#    depth:7
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001880': GOTerm('GO:0001880'):
#    id:GO:0001880
#    item_id:GO:0001880
#    name:Mullerian duct regression
#    namespace:biological_process
#    _parents: 2 items
#      GO:0060033
#      GO:0003006
#    parents: 2 items
#      GO:0060033	level-02	depth-02	anatomical structure regression [biological_process]
#      GO:0003006	level-02	depth-02	developmental process involved in reproduction [biological_process]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001881': GOTerm('GO:0001881'):
#    id:GO:0001881
#    item_id:GO:0001881
#    name:receptor recycling
#    namespace:biological_process
#    _parents: 1 items
#      GO:0043112
#    parents: 1 items
#      GO:0043112	level-04	depth-05	receptor metabolic process [biological_process]
#    children: 4 items
#      GO:0016562	level-06	depth-07	protein import into peroxisome matrix, receptor recycling [biological_process]
#      GO:0038019	level-06	depth-07	Wnt receptor recycling [biological_process]
#      GO:0038020	level-06	depth-07	insulin receptor recycling [biological_process]
#      GO:0006934	level-06	depth-07	substrate-bound cell migration, adhesion receptor recycling [biological_process]
#    level:5
#    depth:6
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001882': GOTerm('GO:0001882'):
#    id:GO:0001882
#    item_id:GO:0001882
#    name:nucleoside binding
#    namespace:molecular_function
#    _parents: 4 items
#      GO:0097159
#      GO:0036094
#      GO:0097367
#      GO:1901363
#    parents: 4 items
#      GO:0097367	level-02	depth-02	carbohydrate derivative binding [molecular_function]
#      GO:0097159	level-02	depth-02	organic cyclic compound binding [molecular_function]
#      GO:0036094	level-02	depth-02	small molecule binding [molecular_function]
#      GO:1901363	level-02	depth-02	heterocyclic compound binding [molecular_function]
#    children: 4 items
#      GO:0032546	level-04	depth-04	deoxyribonucleoside binding [molecular_function]
#      GO:0032549	level-04	depth-04	ribonucleoside binding [molecular_function]
#      GO:0001883	level-04	depth-04	purine nucleoside binding [molecular_function]
#      GO:0001884	level-04	depth-04	pyrimidine nucleoside binding [molecular_function]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  'GO:0001883': GOTerm('GO:0001883'):
#    id:GO:0001883
#    item_id:GO:0001883
#    name:purine nucleoside binding
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0001882
#    parents: 1 items
#      GO:0001882	level-03	depth-03	nucleoside binding [molecular_function]
#    children: 2 items
#      GO:0032547	level-05	depth-05	purine deoxyribonucleoside binding [molecular_function]
#      GO:0032550	level-05	depth-05	purine ribonucleoside binding [molecular_function]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  ...}
